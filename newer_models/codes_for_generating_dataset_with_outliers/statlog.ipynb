# %%
import pandas as pd
import numpy as np
import random

# %%
df=pd.read_csv('../../dataset/statlog_data_set.csv')
#adding a new column named result and assigning it to 1
df['result']=1
#displaying the first 5 rows of the dataset
print(df.head())
# Out:
#    a1   a2   a3  a4  a5   a6   a7  a8  a9  a10  ...  a29  a30  a31  a32  a33  \
# 0  92  115  120  94  84  102  106  79  84  102  ...   88  121  128  100   84
# 1  84  102  106  79  84  102  102  83  80  102  ...   84  107  113   87   84
# 2  84  102  102  83  80  102  102  79  84   94  ...   84   99  104   79   84
# 3  80  102  102  79  84   94  102  79  80   94  ...   84   99  104   79   84
# 4  84   94  102  79  80   94   98  76  80  102  ...   84  103  104   79   79
#
#    a34  a35  a36  a37   result
# 0  107  113   87     3       1
# 1   99  104   79     3       1
# 2   99  104   79     3       1
# 3  103  104   79     3       1
# 4  107  109   87     3       1
#
# [5 rows x 38 columns]

# %%
# randomly generating outliners for the dataset and assinging the result column to -1
len_columns=len(df.columns)
len_rows=len(df)
outliers=[]

min_cloumn_values=[]
max_cloumn_values=[]


for i in range(0,len_columns-1):
    min_cloumn_values.append(int(np.percentile(df.iloc[:,i],1)))
    max_cloumn_values.append(int(np.percentile(df.iloc[:,i],99)))


for i in range(0,20):
    temp=[]
    scaling_factor=random.uniform(.5,1.5)
    for j in range(0,len_columns-1):
        temp.append(int(np.random.randint(min_cloumn_values[j],max_cloumn_values[j])*scaling_factor))
    temp.append(-1)
    outliers.append(temp)

print(outliers)
# Out:
# [[73, 126, 112, 194, 100, 81, 122, 85, 63, 47, 178, 75, 122, 162, 109, 93, 101, 171, 177, 107, 100, 168, 150, 90, 138, 110, 180, 97, 84, 134, 118, 128, 113, 125, 121, 84, 7, -1], [61, 58, 68, 62, 75, 46, 73, 100, 71, 66, 67, 86, 87, 63, 64, 85, 74, 70, 112, 93, 59, 39, 79, 51, 62, 38, 98, 47, 68, 44, 73, 104, 88, 63, 72, 111, 2, -1], [68, 78, 167, 93, 120, 109, 148, 107, 60, 94, 136, 166, 85, 128, 130, 128, 68, 94, 128, 134, 85, 91, 95, 95, 97, 98, 147, 122, 125, 52, 94, 130, 97, 151, 161, 68, 4, -1], [62, 134, 175, 115, 65, 72, 137, 81, 127, 158, 105, 122, 61, 48, 157, 184, 131, 41, 143, 181, 120, 50, 180, 97, 108, 72, 167, 145, 108, 122, 175, 163, 110, 164, 145, 197, 4, -1], [33, 44, 70, 89, 42, 51, 55, 83, 39, 48, 82, 71, 58, 59, 58, 35, 46, 58, 74, 69, 32, 60, 76, 36, 33, 69, 82, 35, 61, 64, 72, 82, 33, 56, 60, 51, 3, -1], [104, 111, 150, 80, 95, 74, 109, 142, 100, 42, 150, 137, 58, 134, 105, 147, 98, 110, 82, 95, 54, 74, 142, 118, 74, 61, 82, 115, 52, 110, 155, 151, 58, 61, 121, 67, 1, -1], [72, 100, 96, 108, 38, 51, 59, 84, 67, 60, 60, 89, 56, 50, 110, 84, 61, 50, 83, 123, 38, 89, 84, 101, 43, 35, 97, 91, 85, 91, 117, 89, 66, 51, 108, 95, 1, -1], [86, 105, 132, 120, 89, 73, 128, 138, 51, 89, 86, 114, 92, 105, 89, 61, 56, 61, 131, 110, 71, 76, 126, 77, 79, 142, 116, 76, 65, 55, 101, 161, 104, 71, 106, 71, 2, -1], [70, 76, 105, 175, 115, 59, 104, 186, 85, 76, 180, 101, 105, 121, 160, 150, 120, 70, 102, 188, 121, 62, 114, 92, 72, 136, 104, 191, 65, 149, 102, 157, 123, 79, 127, 75, 8, -1], [71, 52, 124, 139, 56, 118, 117, 96, 104, 68, 112, 84, 100, 49, 111, 71, 63, 119, 116, 136, 105, 96, 75, 114, 75, 73, 82, 102, 104, 94, 101, 90, 68, 106, 113, 82, 6, -1], [40, 31, 83, 85, 44, 26, 52, 106, 64, 77, 95, 75, 40, 27, 85, 91, 59, 50, 71, 66, 37, 57, 67, 40, 53, 25, 51, 66, 40, 59, 99, 98, 47, 65, 80, 64, 4, -1], [40, 24, 94, 51, 42, 37, 52, 80, 39, 75, 55, 86, 57, 37, 55, 75, 40, 67, 82, 48, 53, 83, 83, 48, 38, 83, 52, 79, 41, 26, 61, 43, 51, 51, 62, 59, 2, -1], [84, 63, 128, 115, 45, 38, 95, 140, 93, 50, 111, 114, 50, 124, 91, 62, 52, 34, 91, 113, 73, 121, 86, 120, 64, 98, 131, 144, 96, 80, 128, 126, 48, 57, 83, 125, 6, -1], [39, 56, 58, 57, 39, 50, 40, 48, 33, 27, 61, 66, 52, 28, 64, 61, 33, 25, 40, 64, 47, 49, 44, 44, 35, 48, 60, 34, 32, 32, 49, 36, 31, 46, 66, 48, 3, -1], [77, 57, 179, 176, 64, 104, 122, 162, 111, 82, 112, 94, 88, 47, 116, 188, 79, 42, 168, 109, 136, 64, 135, 165, 126, 102, 168, 101, 97, 135, 161, 126, 87, 158, 126, 104, 8, -1], [29, 53, 78, 64, 51, 58, 53, 34, 53, 24, 50, 86, 63, 20, 82, 84, 46, 20, 51, 89, 61, 74, 75, 37, 62, 28, 57, 87, 63, 36, 59, 62, 49, 27, 85, 48, 3, -1], [58, 74, 120, 95, 56, 40, 117, 118, 48, 41, 131, 58, 45, 68, 108, 133, 78, 42, 101, 133, 90, 51, 126, 86, 53, 55, 130, 71, 87, 83, 133, 99, 63, 44, 92, 84, 2, -1], [61, 85, 110, 166, 114, 59, 115, 89, 56, 108, 110, 108, 96, 50, 143, 102, 125, 96, 94, 79, 93, 96, 162, 150, 83, 133, 134, 147, 108, 126, 163, 163, 57, 115, 160, 166, 1, -1], [132, 159, 151, 117, 102, 77, 101, 186, 130, 107, 117, 186, 96, 76, 184, 86, 117, 117, 115, 92, 120, 145, 183, 203, 139, 162, 108, 142, 77, 154, 174, 92, 117, 77, 151, 76, 5, -1], [120, 132, 122, 199, 64, 162, 128, 162, 101, 65, 114, 186, 135, 101, 180, 184, 103, 96, 189, 116, 109, 43, 151, 168, 78, 173, 116, 87, 78, 69, 157, 106, 116, 148, 184, 157, 8, -1]]

# %%
#adding outliers to the dataset and shuffling the dataset
for i in range(0,len(outliers)):
    df.loc[len_rows+i]=outliers[i]

df=df.sample(frac=1).reset_index(drop=True)
print(df.head())
# Out:
#    a1  a2   a3  a4  a5  a6   a7  a8  a9  a10  ...  a29  a30  a31  a32  a33  \
# 0  53  56   97  90  60  56   93  87  57   60  ...   56   54   87   78   56
# 1  53  51   75  59  53  51   75  59  53   57  ...   56   56   84   78   56
# 2  71  77   82  64  71  81   82  68  71   77  ...   76   85   86   72   68
# 3  84  99  100  79  84  95   96  79  71   83  ...   83   91  101   79   79
# 4  75  95  104  87  71  95  104  87  75   91  ...   67   84   93   83   67
#
#    a34  a35  a36  a37   result
# 0   57   87   70     5       1
# 1   63   88   78     5       1
# 2   85   86   68     7       1
# 3   95   93   75     4       1
# 4   84   97   83     1       1
#
# [5 rows x 38 columns]

# %%
#saving the dataset to a new csv file
df.to_csv('../generated_datasets/statlog_with_outliers.csv',index=False)
